# %%
# !nvidia-smi
# Out:
# Tue Jul 16 08:55:44 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics==8.0.20
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.4/78.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/week 2 assignment
# Out:
# /content/drive/MyDrive/week 2 assignment

# %%
# !unzip dataset.zip -d /content/datasets
None
# Out:
# Archive:  dataset.zip
#   inflating: /content/datasets/data.yaml
#   inflating: /content/datasets/valid/labels.cache
#   inflating: /content/datasets/test/images/Cars343_png.rf.1faf32b05c2b6bb56b93e41b49b56db9.jpg
#   inflating: /content/datasets/test/images/Cars411_png.rf.7b08e44315268c4a52fec6cb2901269b.jpg
#   inflating: /content/datasets/test/images/no_damage_61_jpg.rf.da3fb178d525d122b51abdbc9d072f99.jpg
#   inflating: /content/datasets/test/images/Cars306_png.rf.dd001ad2f0e6c305bf5bd3d704eebd75.jpg
#   inflating: /content/datasets/test/images/Cars212_png.rf.c31b66dbfb5e4d5bc2e10f4b331f03aa.jpg
#   inflating: /content/datasets/test/images/Cars54_png.rf.343c552d210654b382802f7e663236e5.jpg
#   inflating: /content/datasets/test/images/Cars304_png.rf.f31408152fe09e73a74c2949a65058a0.jpg
#   inflating: /content/datasets/test/labels/no_damage_61_jpg.rf.da3fb178d525d122b51abdbc9d072f99.txt
# ...

# %%
#!ls /content/MyDrive/car/test/label/test-20240712T040003Z-001/test
# Out:
# ls: cannot access '/content/MyDrive/car/test/label/test-20240712T040003Z-001/test': No such file or directory

# %%
#%cd /content/dataset

# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=25 imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=runs/detect/train3/weights/best.pt data=data.yaml
# Out:
# 2024-07-16 10:35:14.714490: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-16 10:35:14.714571: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-16 10:35:14.716135: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-16 10:35:14.723875: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train3/weights/best.pt conf=0.25 source=/content/dataset/test/images
# Out:
# 2024-07-16 10:37:09.167217: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-16 10:37:09.167277: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-16 10:37:09.168723: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-16 10:37:09.175966: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
